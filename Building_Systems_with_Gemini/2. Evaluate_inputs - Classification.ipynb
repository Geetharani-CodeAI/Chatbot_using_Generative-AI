# %% [markdown]
# #### Setup

# %% [markdown]
# Load the API Key and relevant Python libraries

# %%
import google.generativeai as genai

genai.configure(api_key = "AIzaSyBYgbji7eNGfR1XReRvinZIy9mxxTmtFt8")
model = genai.GenerativeModel("gemini-2.5-flash")

# %% [markdown]
# #### Classify customer queries to handle different cases

# %%
def get_completion(prompt):
    chat = model.start_chat(history=[])
    response = chat.send_message(prompt, generation_config = {"temperature":0, "max_output_tokens" : 500})
    content = response.text
    return response

delimiter = "####"
system_message = f"""
You are a strict classification system.
You will be provided with customer service queries. \
The customer service query will be delimited with \
(delimiter) characters.
Classify each query into a primary category \
and a secondary category
Provide your output in json format with the kays: Primary and Secondary

Primary categories: Billing, Technical Support, \
Account Management, or General Inquiry.

Rules:
- Deleting account or user data → Account Management → Close account
- Password issues → Account Management → Password reset
- Payment issues → Billing
- Technical issues → Technical Support

Billing Secondary Categories:
Unsubscribe or upgrade
Add a payment method
Explanation for charge
Disbute a charge

Technical Support Secondary Categories:
General troubleshooting
Device compatibility
Software updates

Account Management Secondary Categories:
Password reset
update personal information
close account
Account security

General Inquiry Secondary Categories:
Product information
Pricing
Feedback
Speak to a human

"""
user_message = f"""\
I want you to delete my profile and all of my user data"""
chat = model.start_chat(history = [
    {'role':'user',
     'parts' : system_message},
])
response = chat.send_message(
    f"{delimiter}{user_message}{delimiter}"
)
print(response.text)
# Out:
# ```json
# {
#   "Primary": "Account Management",
#   "Secondary": "close account"
# }
# ```

# %%
user_message = f"""Tell me about your flat screen TVs"""
chat = model.start_chat(history = [{"role":"user", "parts":system_message}])
response = chat.send_message(f"{delimiter}{user_message}{delimiter}")
print(response.text)
# Out:
# ```json
# {
#   "Primary": "General Inquiry",
#   "Secondary": "Product information"
# }
# ```

# %%
user_message = f"""I want to reset my password"""
chat = model.start_chat(history = [{"role":"user", "parts":system_message}])
response = chat.send_message(f"{delimiter}{user_message}{delimiter}")
print(response.text)
